# %%
import VESIcal as v
import Thermobar as pt

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
import multiprocessing

# %%
out=pt.import_excel('MI_compilation_XH2O.xlsx', sheet_name="Hauri_Borgarhraun_2017")
my_input=out['my_input']
myOls=out['Ols']
myLiquids1=out['Liqs']

## Lets check the outputs have loaded right
display(myOls.head())
display(myLiquids1.head())
# Out:
#    SiO2_Ol   TiO2_Ol  Al2O3_Ol  FeOt_Ol  MnO_Ol  MgO_Ol  CaO_Ol  Na2O_Ol  \
# 0   51.698  0.122000     5.180      0.0     0.0  17.713  20.195    0.221
# 1   51.621  0.147411     5.057      0.0     0.0  17.594  20.023    0.213
# 2   51.621  0.147411     5.057      0.0     0.0  17.594  20.023    0.213
# 3   40.388  0.002500     0.079      0.0     0.0  48.404   0.258    0.000
# 4   40.484  0.002900     0.068      0.0     0.0  48.672   0.259    0.000
#
#    K2O_Ol  Cr2O3_Ol  NiO_Ol                Sample_ID_Ol
# 0     0.0  0.978000     0.0  Hauri_2017_Borgarhraun_167
# 1     0.0  1.203138     0.0   Hauri_2017_Borgarhraun_57
# 2     0.0  1.203138     0.0   Hauri_2017_Borgarhraun_40
# 3     0.0  0.000000     0.0   Hauri_2017_Borgarhraun_11
# 4     0.0  0.000000     0.0  Hauri_2017_Borgarhraun_143
#    SiO2_Liq  TiO2_Liq  Al2O3_Liq  FeOt_Liq   MnO_Liq  MgO_Liq  CaO_Liq  \
# 0   47.7630    0.4859     14.106   10.0054  0.000000   11.925  12.6090
# 1   47.9140    0.4386     14.572    9.9064  0.144206   11.797  12.7150
# 2   47.9470    0.5762     14.581    9.7570  0.148420   11.726  12.5290
# 3   47.9630    0.7611     15.049    9.9874  0.145239   10.605  13.2020
# 4   47.9705    0.7052     14.102   10.5202  0.165940   10.455  12.5575
#
#    Na2O_Liq   K2O_Liq  Cr2O3_Liq  P2O5_Liq   H2O_Liq  Fe3Fet_Liq  NiO_Liq  \
# 0     1.583  0.000497        0.0  0.000442  0.118336         0.0      0.0
# 1     1.513  0.000322        0.0  0.000449  0.120171         0.0      0.0
# 2     1.513  0.000285        0.0  0.000491  0.104616         0.0      0.0
# 3     1.584  0.000286        0.0  0.000553  0.158056         0.0      0.0
# 4     1.797  0.000784        0.0  0.000486  0.198352         0.0      0.0
#
#    CoO_Liq   CO2_Liq               Sample_ID_Liq
# 0      0.0  0.066379  Hauri_2017_Borgarhraun_167
# 1      0.0  0.034125   Hauri_2017_Borgarhraun_57
# 2      0.0  0.026894   Hauri_2017_Borgarhraun_40
# 3      0.0  0.018100   Hauri_2017_Borgarhraun_11
# 4      0.0  0.058420  Hauri_2017_Borgarhraun_143

# %%
T_HT87=pt.calculate_liq_only_temp(liq_comps=myLiquids1, equationT="T_Helz1987_CaO")
df_HT87=pt.convert_to_vesical(liq_comps=myLiquids1,
                              T1=T_HT87, unit='Kelvin', Fe3Fet_Liq=0.15)
df_HT87.head()
# Out:
#       SiO2    TiO2   Al2O3       MnO     MgO      CaO   Na2O       K2O  Cr2O3  \
# Hauri_2017_Borgarhraun_10   12.7920  1.322  0.000000    0.0  0.000000
# Hauri_2017_Borgarhraun_19   12.9960  1.357  0.000000    0.0  0.000000
# Hauri_2017_Borgarhraun_89   13.0525  1.370  0.000000    0.0  0.000000
#
#                                  H2O  NiO  CoO       CO2       Temp      FeO  \
# Hauri_2017_Borgarhraun_167  0.118336  0.0  0.0  0.066379  1177.3094  8.50459
# Hauri_2017_Borgarhraun_57   0.120171  0.0  0.0  0.034125  1179.0690  8.42044
# Hauri_2017_Borgarhraun_40   0.104616  0.0  0.0  0.026894  1175.9814  8.29345
# Hauri_2017_Borgarhraun_11   0.158056  0.0  0.0  0.018100  1187.1532  8.48929
# Hauri_2017_Borgarhraun_143  0.198352  0.0  0.0  0.058420  1176.4545  8.94217
# ...                              ...  ...  ...       ...        ...      ...
# Hauri_2017_Borgarhraun_21   0.125202  0.0  0.0  0.015602  1188.4729  8.36536
# Hauri_2017_Borgarhraun_144  0.128250  0.0  0.0  0.059014  1169.4991  8.29039
# Hauri_2017_Borgarhraun_10   0.087490  0.0  0.0  0.010298  1180.3472  8.71420
# Hauri_2017_Borgarhraun_19   0.134718  0.0  0.0  0.014920  1183.7336  7.35403
# Hauri_2017_Borgarhraun_89   0.122273  0.0  0.0  0.044299  1184.6715  7.18726
#
#                                Fe2O3
# Hauri_2017_Borgarhraun_167  1.667566
# Hauri_2017_Borgarhraun_57   1.651067
# Hauri_2017_Borgarhraun_40   1.626167
# Hauri_2017_Borgarhraun_11   1.664567
# Hauri_2017_Borgarhraun_143  1.753366
# ...                              ...
# Hauri_2017_Borgarhraun_21   1.640267
# Hauri_2017_Borgarhraun_144  1.625567
# Hauri_2017_Borgarhraun_10   1.708666
# Hauri_2017_Borgarhraun_19   1.441967
# Hauri_2017_Borgarhraun_89   1.409267
#
# [153 rows x 17 columns]

# %%
df= VESIcal_out.get_data()
chunk_size = 25
subframes = [v.BatchFile(filename=None,dataframe=df.iloc[i:i+chunk_size],label=None) for i in range(0, len(df), chunk_size)]

# %%
for index, data in enumerate(subframes):
        Sat_P_MagmaSat = data.calculate_saturation_pressure(temperature="Temp")
        filename = f"XH2O_Hauri_Borgarhraun_2017_{index}.xlsx"
        Sat_P_MagmaSat.to_excel(excel_writer=filename)
# Out:
# [====================] 100%  Working on sample Hauri_2017_Borgarhraun_1...
# [====================] 100%  Working on sample Hauri_2017_Borgarhraun_5
# [====================] 100%  Working on sample Hauri_2017_Borgarhraun_1...
# [====================] 100%  Working on sample Hauri_2017_Borgarhraun_1...
# [===========         ] 56%  Working on sample Hauri_2017_Borgarhraun_1...

# %%
import os
combined_data = pd.DataFrame()

for index in range(len(subframes)):
    filename = f"XH2O_Hauri_Borgarhraun_2017_{index}.xlsx"
    if os.path.exists(filename):
        df = pd.read_excel(filename)
        combined_data = pd.concat([combined_data, df])

combined_filename = "XH2O_Hauri_Borgarhraun_2017_combined.xlsx"
combined_data.to_excel(combined_filename, index=False)
